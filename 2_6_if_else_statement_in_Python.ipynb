# %% [markdown]
# <a href="https://colab.research.google.com/github/priyankapanda545-ux/Fake-News-Detection-using-DeepLearning/blob/main/2_6_if_else_statement_in_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Simple if else statement

# %%
a = 30
b = 50

if(a >b):
  print("a is the greatest number.")
else:
  print("b is the greatest number")
# Out:
# b is the greater number

# %%
a = int(input("Enter the first number: "))
b = int(input("Enter the second number: "))

if(a >b):
  print("First number is the greatest.")
else:
  print("Second number is the greatest.")
# Out:
# Enter the first number: 150
# Enter the second number: 100
# First number is the greatest.

# %% [markdown]
# if elif else statement

# %%
a = 15
b = 25
c = 30

if(b < a > c):
  print("a is greatest number")
elif(a < b > c):
  print("b is greatest number")
else:
  print("c is greatest number")
# Out:
# c is greatest number

# %% [markdown]
# nested if statement

# %%
a = 20
b = 40
c = 60

if(a>b):
  if(a>c):
    print("a is the greatest number")
  else:
    print("c is the greatest number")
else:
  if(b > c):
    print("b is the greatest number")
  else:
      print("c is the greatest number")
# Out:
# c is the greatest number
