# %% [markdown]
# <a href="https://colab.research.google.com/github/priyankapanda545-ux/Fake-News-Detection-using-DeepLearning/blob/main/2_8_Functions_in_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Functions:
#
# Function is a block of code that can be reused in a Program.

# %% [markdown]
# Factorial of a Number

# %% [markdown]
# Factorial of a number is the product of all positive integers less than or equal to the given number.

# %% [markdown]
# Factorial of 5 = 5*4*3*2*1 = 120

# %%
num = int(input("Enter a number to find its factorial: "))

factorial = 1

if num == 0:
  print("The factorial of 0 is 1")

else:
  for i in range(1, num+1):
    factorial = factorial * i
  print("The Factorial of " ,num ,"is", factorial)
# Out:
# Enter a number to find its factorial: 10
# The Factorial of  10 is 3628800

# %% [markdown]
# #Factorial Function

# %%
def factorial_value(num):
  factorial = 1
  if num == 0:
    return factorial
  else:
     for i in range(1, num+1):
      factorial = factorial*i
     return factorial

# %%
print(factorial_value(5))
# Out:
# 120

# %%
print(factorial_value(10))
# Out:
# 3628800

# %%
print(factorial_value(6))
# Out:
# 720
