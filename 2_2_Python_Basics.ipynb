# %% [markdown]
# <a href="https://colab.research.google.com/github/priyankapanda545-ux/Fake-News-Detection-using-DeepLearning/blob/main/2_2_Python_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Programming languages used forMachine Learning
# 1. Python
# 2. R

# %% [markdown]
# #Print Function

# %%
print("Machine Learning")
# Out:
# Machine Learning

# %%
print("Machine Learning" + " Projects")
print("Machine Learning" + "Projects")
# Out:
# Machine Learning Projects
# Machine LearningProjects

# %%
print(8)
# Out:
# 8

# %%
print(8+3)
# Out:
# 11

# %% [markdown]
# #**Basic Data Types:**
# 1. int
#
# 2. float
#
# 3. str

# %%
type(8)
# Out:
# int

# %%
type(8.5)
# Out:
# float

# %%
type("Priyanka Panda")
# Out:
# str

# %% [markdown]
# #Constants and Variables

# %%
super_hero = "Iron Man"
print(super_hero)
# Out:
# Iron Man

# %%
marvel_super_hero = "Captain America"
print(marvel_super_hero)
# Out:
# Captain America

# %%
hero1, hero2, hero3 = "Iron Man", "Captain America", "Bat Man"
print(hero1)
print(hero2)
print(hero3)
# Out:
# Iron Man
# Captain America
# Bat Man

# %%
x = y = z = 23
print(x)
print(y)
print(z)
# Out:
# 23
# 23
# 23

# %% [markdown]
# #Input Function:

# %%
number_1 = input("Enter the first number: ")
# Out:
# Enter the first number: 23

# %%
number_2 = input("Enter the second number: ")
# Out:
# Enter the second number: 28

# %%
number_1 = int(input("Enter the first number: "))
number_2 = int(input("Enter the second number: "))

sum = number_1 + number_2
print(sum)
# Out:
# Enter the first number: 25
# Enter the second number: 23
# 48

# %%
#changing the data type in python
num = 5

print(float(num))
type(num)
# Out:
# 5.0
# int
